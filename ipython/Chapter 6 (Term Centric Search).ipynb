# %% [markdown]
# # Setup Code from Prev Chapters (run first)

# %%
import requests
import json
import os

# Some utilities for flattening the explain into something a bit more
# readable. Pass Explain JSON, get something readable (ironically this is what Solr's default output is :-p)
def flatten(l):
    [item for sublist in l for item in sublist]

def simplerExplain(explainJson, depth=0):
    result = " " * (depth * 2) + "%s, %s\n" % (explainJson['value'], explainJson['description'])
    #print json.dumps(explainJson, indent=True)
    if 'details' in explainJson:
        for detail in explainJson['details']:
            result += simplerExplain(detail, depth=depth+1)
    return result


# To speed up the pace of development, we really need to focus more heavily on the analysis and query
# settings of the search engine, rather than fidly bits of the http interface.
#
# To that end, we're going to collapse some of the code you were introduced to in chapter 3 into more general functions,
# so we can reuse them. Largely, this is the exact same code you saw in chapter 3 some more generality.

## Analyze
## The analyze function is a helper for accessing the _analyze endpoint like we did in chapter 3. Recall,
## given a field or analyzer, passing some text to _analyze will return the token stream that results from
## that analyzer. This token stream, if you recall, shows us exactly how the search engine translate text
## into individual tokens to be consumed by the underlying data structures. When we debug analysis, we see
## matches we need to expect.
def analyze(text, field=None, analyzer=None):
    whatToAnalyze = ''
    if field is not None:
        whatToAnalyze = "field=%s" % field
    elif analyzer is not None:
        whatToAnalyze = "analyzer=%s" % analyzer
    resp = requests.get("http://localhost:9200/tmdb/_analyze?%s&format=yaml", whatToAnalyze, 
                        json={'field': field, 'analyzer': analyzer, 'text':text})
    print(resp.text)
    
## Search
## Next we need to wrap up our execution of query DSL queries. The function 'search' will execute the passed query DSL
## query and display the results. 
## If a scoring explain is associated with the results, then it also gets displayed,
## We'll also be sure to dump the query DSL
def search(query, verbose=False):
    url = 'http://localhost:9200/tmdb/movie/_search'
    httpResp = requests.get(url, json=query)
    if httpResp.status_code != 200:
        print("Search Failed <%s>" % httpResp.status_code)
        print("%s" % httpResp.text)
    searchHits = json.loads(httpResp.text)['hits']
    print("Num\tRelevance Score\t\tMovie Title")
    for idx, hit in enumerate(searchHits['hits']):
            castNames = []            
            castCharacters = []                        
            directorNames = []
            for cast in hit['_source']['cast']:
                castNames.append(cast['name'])
                castCharacters.append(cast['character'])
            for director in hit['_source']['directors']:
                directorNames.append(director['name'])
            print("%s\t%s\t\t%s" % (idx + 1, hit['_score'], hit['_source']['title']))
            if verbose:
                print("%s" % hit['_source']['title'])
                print("%s" % hit['_source']['tagline'])      
                print("%s" % hit['_source']['overview'])
                print("%s" % hit['_id'])
                print("DIRS %s" % directorNames)
                print("CAST %s" % castNames)
                print("CHAR %s" % castCharacters)
                if '_explanation' in hit:
                    print("%s" % simplerExplain(hit['_explanation']))
                    print("*************************************")
    
    if verbose:
        httpResp = requests.get('http://localhost:9200' + 
                    '/tmdb/movie/_validate/query?explain',
                     json={'query': query['query']})
        print(json.loads(httpResp.text))

## Reindex
## Reindex takes analyzer and field mappings, recreates the index, and then reindexes
## TMDB movies using the _bulk index API. There are other ways for modifying the configuration
## of the index besides dropping and restarting, however for convenience and because our data
## isn't truly that large, we'll just delete and start from scratch when we need to.
def reindex(analysisSettings, mappingSettings=None, movieDict={}):
    # Destroy any existing index (equiv to SQL "drop table")
    resp = requests.delete("http://localhost:9200/tmdb")
    print("Delete TMDB Index <%s>" % resp.status_code)
    
    # Create the index with explicit settings
    # We need to explicitely set number of shards to 1 to eliminate the impact of 
    # distributed IDF on our small collection
    # See also "Relavance is Broken!"
    # http://www.elastic.co/guide/en/elasticsearch/guide/current/relevance-is-broken.html
    settings = {
        "settings": {
            "number_of_shards": 1,
            "index": {
                "analysis" : analysisSettings,
            }
        }
    }
    if mappingSettings:
        settings['mappings'] = mappingSettings
    resp = requests.put("http://localhost:9200/tmdb", json=settings)
    print("Create TMDB Index <%s>" % resp.status_code)
    if resp.status_code != 200:
        print(resp.text)
    
    # Bulk index title & overview to the movie endpoint
    print("Indexing %i movies" % len(movieDict.keys()))
    bulkMovies = ""
    for id, movie in movieDict.items():
        addCmd = {"index": {"_index": "tmdb", "_type": "movie", "_id": movie["id"]}}
        esDoc  = movie
        bulkMovies += json.dumps(addCmd) + "\n" + json.dumps(esDoc) + "\n"
    resp = requests.post("http://localhost:9200/_bulk", data=bulkMovies, headers={"Content-Type":"application/x-ndjson"})
    print("Bulk Index into TMDB Index <%s>" % resp.status_code)

## Extract
## major difference between our use of TMDB here and in chapter 3: pulling more data. Not only do we access the 
## movie endpoint, we also extract the credits -- pulling in the cast (actors and such) and extracting the director.
def extract(movieIds=[], numMovies=10000):
    if len(movieIds) == 0:
        try:
            f = open('tmdb.json')
            if f:
                return json.loads(f.read());
        except IOError:
            pass       
    return movieDict

# %% [markdown]
# # Index to ES, Chapter 5 Settings

# %%
movieDict = extract([])

analysisSettings = {
   "analyzer" : {
      "default" : {
        "type" : "english"
      },
      "english_bigrams": {
          "type": "custom",
          "tokenizer": "standard",
          "filter": [
            "standard",
            "lowercase",
            "porter_stem",
            "bigram_filter"
          ]
      }
    },
  "filter": {
    "bigram_filter": {
        "type": "shingle",
        "max_shingle_size":2,
        "min_shingle_size":2,
        "output_unigrams":"false"
    }
  }
}

            
mappingSettings = {
    'movie': {
        'properties': {
            "cast": {
               'properties': {
                  'name': {
                      'type': 'text',
                      'analyzer': 'english',
                      'fields': {
                         "bigramed": {
                            "type": "text",
                            "analyzer": "english_bigrams"
                        }     
                      }
                   }
                   
               }
            },
            "directors": {
               'properties': {
                  'name': {
                      'type': 'text',
                      'analyzer': 'english',
                      'fields': {
                         "bigramed": {
                            "type": "text",
                            "analyzer": "english_bigrams"
                        }     
                      }
                   }
                   
               }
            }            
        }
    }
}

reindex(analysisSettings, mappingSettings, movieDict)
# Out:
# Delete TMDB Index <200>
# Create TMDB Index <200>
# Indexing 3051 movies
# Bulk Index into TMDB Index <200>

# %% [markdown]
# # 6.2.2, Listing 3 -- Most Fields undue promotion due to director AND cast member

# %%
usersSearch = 'star trek patrick stewart william shatner'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview', 'cast.name.bigramed', 'directors.name.bigramed'],      
            'type': 'most_fields'
         }
    },
    'size': 5,
    'explain': True
}
search(query, True)
# Out:
# Num	Relevance Score		Movie Title
# 1	22.85533		Star Trek: Generations
# Star Trek: Generations
# Boldly go.
# Captain Jean-Luc Picard and the crew of the Enterprise-D find themselves at odds with the renegade scientist Soran who is destroying entire star systems. Only one man can help Picard stop Soran's scheme...and he's been dead for seventy-eight years.
# 193
# DIRS ['David Carson']
# CAST ['Patrick Stewart', 'Jonathan Frakes', 'Brent Spiner', 'LeVar Burton', 'Michael Dorn', 'Gates McFadden', 'Marina Sirtis', 'William Shatner', 'James Doohan', 'Walter Koenig', 'Malcolm McDowell', 'Alan Ruck', 'Whoopi Goldberg', 'Thomas Dekker', 'Cameron Oppenheimer', 'Jenette Goldstein', 'Tim Russ']
# CHAR ['Captain Jean-Luc Picard', 'Commander William T. Riker', 'Lt. Commander Data', 'Lt. Commander Geordi La Forge', 'Lt. Commander Worf', 'Dr. Beverly Crusher', 'Commander Deanna Troi', 'James T. Kirk', 'Montgomery Scott', 'Pavel Chekov', 'Dr. Tolian Soran', 'Capt. John Harriman', 'Guinan', "Picard's Kid", 'Ensign Kellogg', 'Science Officer', 'Lieutenant']
# 22.855328, sum of:
#   3.2777627, sum of:
#     3.2777627, weight(overview:star in 124) [PerFieldSimilarity], result of:
#       3.2777627, score(doc=124,freq=1.0 = termFreq=1.0
# ), product of:
#         3.14339, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           90.0, docFreq
#           2097.0, docCount
#         1.0427477, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           36.67525, avgFieldLength
#           33.0, fieldLength
#   8.666756, sum of:
#     4.064497, weight(title:star in 124) [PerFieldSimilarity], result of:
#       4.064497, score(doc=124,freq=1.0 = termFreq=1.0
# ), product of:
#         4.678802, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           19.0, docFreq
#           2098.0, docCount
#         0.8687046, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.1906579, avgFieldLength
#           3.0, fieldLength
#     4.602259, weight(title:trek in 124) [PerFieldSimilarity], result of:
#       4.602259, score(doc=124,freq=1.0 = termFreq=1.0
# ), product of:
#         5.297841, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           10.0, docFreq
#           2098.0, docCount
#         0.8687046, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.1906579, avgFieldLength
#           3.0, fieldLength
#   10.91081, sum of:
#     5.3700857, weight(cast.name.bigramed:patrick stewart in 124) [PerFieldSimilarity], result of:
#       5.3700857, score(doc=124,freq=1.0 = termFreq=1.0
# ), product of:
#         5.04605, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           13.0, docFreq
#           2097.0, docCount
#         1.0642157, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           19.941345, avgFieldLength
#           17.0, fieldLength
#     5.5407248, weight(cast.name.bigramed:william shatner in 124) [PerFieldSimilarity], result of:
#       5.5407248, score(doc=124,freq=1.0 = termFreq=1.0
# ), product of:
#         5.206393, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           11.0, docFreq
#           2097.0, docCount
#         1.0642157, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           19.941345, avgFieldLength
#           17.0, fieldLength
#
# *************************************
# 2	21.79765		Star Trek IV: The Voyage Home
# Star Trek IV: The Voyage Home
# The key to saving the future can only be found in the past.
# Fugitives of the Federation for their daring rescue of Spock from the doomed Genesis Planet, Admiral Kirk (William Shatner) and his crew begin their journey home to face justice for their actions. But as they near Earth, they find it at the mercy of a mysterious alien presence whose signals are slowly destroying the planet. In a desperate attempt to answer the call of the probe, Kirk and his crew race back to the late twentieth century. However they soon find the world they once knew to be more alien than anything they've encountered in the far reaches of the galaxy!
# 168
# DIRS ['Leonard Nimoy']
# CAST ['William Shatner', 'Leonard Nimoy', 'DeForest Kelley', 'James Doohan', 'George Takei', 'Walter Koenig', 'Nichelle Nichols', 'Jane Wyatt', 'Catherine Hicks', 'Mark Lenard', 'Robin Curtis', 'Robert Ellenstein', 'John Schuck', 'Brock Peters', 'Michael Snyder']
# CHAR ['Admiral/Captain James T. Kirk', 'Captain Spock', 'Dr. Leonard McCoy', 'Montgomery Scott', 'Cmdr. Hikaru Sulu', 'Cmdr. Pavel Chekov', 'Cmdr. Uhura', 'Amanda', 'Dr. Gillian Taylor', 'Ambassador Sarek', 'Lt. Saavik', 'Federation Council President', 'Klingon Ambassador', 'Admiral Cartwright', 'Starfleet Communications Officer']
# 21.797647, sum of:
#   9.460281, sum of:
#     3.712444, weight(overview:william in 105) [PerFieldSimilarity], result of:
#       3.712444, score(doc=105,freq=1.0 = termFreq=1.0
# ), product of:
#         4.678325, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           19.0, docFreq
#           2097.0, docCount
#         0.79354125, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           36.67525, avgFieldLength
#           60.0, fieldLength
#     5.747837, weight(overview:shatner in 105) [PerFieldSimilarity], result of:
#       5.747837, score(doc=105,freq=1.0 = termFreq=1.0
# ), product of:
#         7.2432747, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           1.0, docFreq
#           2097.0, docCount
#         0.79354125, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           36.67525, avgFieldLength
#           60.0, fieldLength
#   6.5436654, sum of:
#     3.0688193, weight(title:star in 105) [PerFieldSimilarity], result of:
#       3.0688193, score(doc=105,freq=1.0 = termFreq=1.0
# ), product of:
#         4.678802, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           19.0, docFreq
#           2098.0, docCount
#         0.6558985, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.1906579, avgFieldLength
#           5.0, fieldLength
#     3.4748461, weight(title:trek in 105) [PerFieldSimilarity], result of:
#       3.4748461, score(doc=105,freq=1.0 = termFreq=1.0
# ), product of:
#         5.297841, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           10.0, docFreq
#           2098.0, docCount
#         0.6558985, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.1906579, avgFieldLength
#           5.0, fieldLength
#   5.7937016, sum of:
#     5.7937016, weight(cast.name.bigramed:william shatner in 105) [PerFieldSimilarity], result of:
#       5.7937016, score(doc=105,freq=1.0 = termFreq=1.0
# ), product of:
#         5.206393, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           11.0, docFreq
#           2097.0, docCount
#         1.1128054, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           19.941345, avgFieldLength
#           15.0, fieldLength
#
# *************************************
# 3	20.275587		Star Trek V: The Final Frontier
# Star Trek V: The Final Frontier
# Adventure and imagination will meet at the final frontier.
# Capt. Kirk and his crew must deal with Mr. Spock's half brother who kidnaps three diplomats and hijacks the Enterprise in his obsessive search for God.
# 172
# DIRS ['William Shatner']
# CAST ['William Shatner', 'Leonard Nimoy', 'DeForest Kelley', 'James Doohan', 'George Takei', 'Nichelle Nichols', 'Walter Koenig', 'David Warner', 'Laurence Luckinbill', 'Charles Cooper', 'Cynthia Gouw', 'Todd Bryant', 'George Murdock', 'Jonathan Simpson']
# CHAR ['Captain James T. Kirk', 'Captain Spock', 'Dr. Leonard McCoy', 'Montgomery Scott', 'Cmdr. Hikaru Sulu', 'Cmdr. Uhura', 'Cmdr. Pavel Chekov', 'St. John Talbot', 'Sybok', 'Gen. Korrd', 'Caithlin Dar', 'Capt. Klaa', 'God', 'Young Sarek']
# 20.275587, sum of:
#   7.802866, sum of:
#     7.802866, weight(directors.name.bigramed:william shatner in 109) [PerFieldSimilarity], result of:
#       7.802866, score(doc=109,freq=1.0 = termFreq=1.0
# ), product of:
#         7.2408886, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           1.0, docFreq
#           2092.0, docCount
#         1.0776117, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           1.2136711, avgFieldLength
#           1.0, fieldLength
#   6.5436654, sum of:
#     3.0688193, weight(title:star in 109) [PerFieldSimilarity], result of:
#       3.0688193, score(doc=109,freq=1.0 = termFreq=1.0
# ), product of:
#         4.678802, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           19.0, docFreq
#           2098.0, docCount
#         0.6558985, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.1906579, avgFieldLength
#           5.0, fieldLength
#     3.4748461, weight(title:trek in 109) [PerFieldSimilarity], result of:
#       3.4748461, score(doc=109,freq=1.0 = termFreq=1.0
# ), product of:
#         5.297841, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           10.0, docFreq
#           2098.0, docCount
#         0.6558985, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.1906579, avgFieldLength
#           5.0, fieldLength
#   5.9290557, sum of:
#     5.9290557, weight(cast.name.bigramed:william shatner in 109) [PerFieldSimilarity], result of:
#       5.9290557, score(doc=109,freq=1.0 = termFreq=1.0
# ), product of:
#         5.206393, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           11.0, docFreq
#           2097.0, docCount
#         1.138803, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           19.941345, avgFieldLength
#           14.0, fieldLength
#
# *************************************
# 4	17.749285		Star Trek: Nemesis
# Star Trek: Nemesis
# A generation's final journey... begins.
# En route to the honeymoon of William Riker to Deanna Troi on her home planet of Betazed, Captain Jean-Luc Picard and the crew of the U.S.S. Enterprise receives word from Starfleet that a coup has resulted in the installation of a new Romulan political leader, Shinzon, who claims to seek peace with the human-backed United Federation of Planets. Once in enemy territory, the captain and his crew make a startling discovery: Shinzon is human, a slave from the Romulan sister planet of Remus, and has a secret, shocking relationship to Picard himself.
# 201
# DIRS ['Stuart Baird']
# CAST ['Patrick Stewart', 'Jonathan Frakes', 'LeVar Burton', 'Brent Spiner', 'Gates McFadden', 'Marina Sirtis', 'Tom Hardy', 'Ron Perlman', 'Shannon Cochran', 'Dina Meyer', 'Michael Dorn', 'Kate Mulgrew', 'Wil Wheaton', 'Whoopi Goldberg', 'Stuart Baird', 'Alan Dale', 'Bryan Singer']
# CHAR ['Captain Jean-Luc Picard', 'Captain William T. Riker', 'Lt. Commander Geordi La Forge', 'Lt. Commander Data', 'Dr. Beverly Crusher', 'Counselor Deanna Troi-Riker', 'Praetor Shinzon', 'The Reman Viceroy', "Senator Tal'aura", 'Commander Donatra', 'Lt. Commander Worf', 'Admiral Janeway', 'Wesley Crusher', 'Guinan', 'Scimitar Computer (voice)', 'Praetor Hiren', 'Kelly (uncredited)']
# 17.749287, sum of:
#   3.712444, sum of:
#     3.712444, weight(overview:william in 230) [PerFieldSimilarity], result of:
#       3.712444, score(doc=230,freq=1.0 = termFreq=1.0
# ), product of:
#         4.678325, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           19.0, docFreq
#           2097.0, docCount
#         0.79354125, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           36.67525, avgFieldLength
#           60.0, fieldLength
#   8.666756, sum of:
#     4.064497, weight(title:star in 230) [PerFieldSimilarity], result of:
#       4.064497, score(doc=230,freq=1.0 = termFreq=1.0
# ), product of:
#         4.678802, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           19.0, docFreq
#           2098.0, docCount
#         0.8687046, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.1906579, avgFieldLength
#           3.0, fieldLength
#     4.602259, weight(title:trek in 230) [PerFieldSimilarity], result of:
#       4.602259, score(doc=230,freq=1.0 = termFreq=1.0
# ), product of:
#         5.297841, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           10.0, docFreq
#           2098.0, docCount
#         0.8687046, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.1906579, avgFieldLength
#           3.0, fieldLength
#   5.3700857, sum of:
#     5.3700857, weight(cast.name.bigramed:patrick stewart in 230) [PerFieldSimilarity], result of:
#       5.3700857, score(doc=230,freq=1.0 = termFreq=1.0
# ), product of:
#         5.04605, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           13.0, docFreq
#           2097.0, docCount
#         1.0642157, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           19.941345, avgFieldLength
#           17.0, fieldLength
#
# *************************************
# 5	14.812269		Hannah Montana: The Movie
# Hannah Montana: The Movie
# She has the best of both worlds...now she has to choose just one.
# When Miley Stewart (aka pop-star Hannah Montana) gets too caught up in the superstar celebrity lifestyle, her dad decides it's time for a total change of scenery. But sweet nibblets! Miley must trade in all the glitz and glamour of Hollywood for some ol' blue jeans on the family farm in Tennessee, and question if she can be both Miley Stewart and Hannah Montana. With a little help from her friends – and awesome guest stars Taylor Swift, Rascal Flatts and Vanessa Williams – will she figure out whether to choose Hannah or Miley?
# 18126
# DIRS ['Peter Chelsom']
# CAST ['Miley Cyrus', 'Billy Ray Cyrus', 'Emily Osment', 'Jason Earles', 'Taylor Swift', 'Lucas Till', 'Mitchel Musso', 'Moisés Arias', 'Vanessa Williams', 'Margo Martindale', 'Melora Hardin', 'Brooke Shields', 'Brandon Cyrus']
# CHAR ['Miley Stewart/Hannah Montana', 'Billy Ray Stewart', 'Lilly Truscott', 'Jackson Rod Stewart', 'Herself', 'Travis Brody', 'Oliver Oken', 'Rico', 'Vita', 'Ruby', 'Lorelai', "Miley's Mom", 'Extra']
# 14.812269, sum of:
#   14.812269, sum of:
#     3.57338, weight(overview:star in 534) [PerFieldSimilarity], result of:
#       3.57338, score(doc=534,freq=2.0 = termFreq=2.0
# ), product of:
#         3.14339, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           90.0, docFreq
#           2097.0, docCount
#         1.1367918, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           2.0, termFreq=2.0
#           1.2, parameter k1
#           0.75, parameter b
#           36.67525, avgFieldLength
#           64.0, fieldLength
#     7.6533933, weight(overview:stewart in 534) [PerFieldSimilarity], result of:
#       7.6533933, score(doc=534,freq=2.0 = termFreq=2.0
# ), product of:
#         6.732449, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           2.0, docFreq
#           2097.0, docCount
#         1.1367918, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           2.0, termFreq=2.0
#           1.2, parameter k1
#           0.75, parameter b
#           36.67525, avgFieldLength
#           64.0, fieldLength
#     3.5854962, weight(overview:william in 534) [PerFieldSimilarity], result of:
#       3.5854962, score(doc=534,freq=1.0 = termFreq=1.0
# ), product of:
#         4.678325, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           19.0, docFreq
#           2097.0, docCount
#         0.76640594, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           36.67525, avgFieldLength
#           64.0, fieldLength
#
# *************************************
# {'_shards': {'total': 1, 'successful': 1, 'failed': 0}, 'valid': True, 'explanations': [{'index': 'tmdb', 'valid': True, 'explanation': '+((directors.name.bigramed:star trek directors.name.bigramed:trek patrick directors.name.bigramed:patrick stewart directors.name.bigramed:stewart william directors.name.bigramed:william shatner) | (overview:star overview:trek overview:patrick overview:stewart overview:william overview:shatner) | (title:star title:trek title:patrick title:stewart title:william title:shatner) | (cast.name.bigramed:star trek cast.name.bigramed:trek patrick cast.name.bigramed:patrick stewart cast.name.bigramed:stewart william cast.name.bigramed:william shatner))~1.0 #*:*'}]}

# %% [markdown]
# # 6.3.2, Listing 7 Query Parser

# %%
usersSearch = 'star trek patrick stewart william shatner'
query = {
    'query': {
        'query_string': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview', 'cast.name.bigramed', 'directors.name.bigramed'],      
         }
    },
    'size': 5,
    'explain': True
}
search(query, True)
# Out:
# Num	Relevance Score		Movie Title
# 1	14.812269		Hannah Montana: The Movie
# Hannah Montana: The Movie
# She has the best of both worlds...now she has to choose just one.
# When Miley Stewart (aka pop-star Hannah Montana) gets too caught up in the superstar celebrity lifestyle, her dad decides it's time for a total change of scenery. But sweet nibblets! Miley must trade in all the glitz and glamour of Hollywood for some ol' blue jeans on the family farm in Tennessee, and question if she can be both Miley Stewart and Hannah Montana. With a little help from her friends – and awesome guest stars Taylor Swift, Rascal Flatts and Vanessa Williams – will she figure out whether to choose Hannah or Miley?
# 18126
# DIRS ['Peter Chelsom']
# CAST ['Miley Cyrus', 'Billy Ray Cyrus', 'Emily Osment', 'Jason Earles', 'Taylor Swift', 'Lucas Till', 'Mitchel Musso', 'Moisés Arias', 'Vanessa Williams', 'Margo Martindale', 'Melora Hardin', 'Brooke Shields', 'Brandon Cyrus']
# CHAR ['Miley Stewart/Hannah Montana', 'Billy Ray Stewart', 'Lilly Truscott', 'Jackson Rod Stewart', 'Herself', 'Travis Brody', 'Oliver Oken', 'Rico', 'Vita', 'Ruby', 'Lorelai', "Miley's Mom", 'Extra']
# 14.812269, max of:
#   14.812269, sum of:
#     3.57338, weight(overview:star in 534) [PerFieldSimilarity], result of:
#       3.57338, score(doc=534,freq=2.0 = termFreq=2.0
# ), product of:
#         3.14339, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           90.0, docFreq
#           2097.0, docCount
#         1.1367918, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           2.0, termFreq=2.0
#           1.2, parameter k1
#           0.75, parameter b
#           36.67525, avgFieldLength
#           64.0, fieldLength
#     7.6533933, weight(overview:stewart in 534) [PerFieldSimilarity], result of:
#       7.6533933, score(doc=534,freq=2.0 = termFreq=2.0
# ), product of:
#         6.732449, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           2.0, docFreq
#           2097.0, docCount
#         1.1367918, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           2.0, termFreq=2.0
#           1.2, parameter k1
#           0.75, parameter b
#           36.67525, avgFieldLength
#           64.0, fieldLength
#     3.5854962, weight(overview:william in 534) [PerFieldSimilarity], result of:
#       3.5854962, score(doc=534,freq=1.0 = termFreq=1.0
# ), product of:
#         4.678325, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           19.0, docFreq
#           2097.0, docCount
#         0.76640594, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           36.67525, avgFieldLength
#           64.0, fieldLength
#
# *************************************
# 2	10.91081		Star Trek: Generations
# Star Trek: Generations
# Boldly go.
# Captain Jean-Luc Picard and the crew of the Enterprise-D find themselves at odds with the renegade scientist Soran who is destroying entire star systems. Only one man can help Picard stop Soran's scheme...and he's been dead for seventy-eight years.
# 193
# DIRS ['David Carson']
# CAST ['Patrick Stewart', 'Jonathan Frakes', 'Brent Spiner', 'LeVar Burton', 'Michael Dorn', 'Gates McFadden', 'Marina Sirtis', 'William Shatner', 'James Doohan', 'Walter Koenig', 'Malcolm McDowell', 'Alan Ruck', 'Whoopi Goldberg', 'Thomas Dekker', 'Cameron Oppenheimer', 'Jenette Goldstein', 'Tim Russ']
# CHAR ['Captain Jean-Luc Picard', 'Commander William T. Riker', 'Lt. Commander Data', 'Lt. Commander Geordi La Forge', 'Lt. Commander Worf', 'Dr. Beverly Crusher', 'Commander Deanna Troi', 'James T. Kirk', 'Montgomery Scott', 'Pavel Chekov', 'Dr. Tolian Soran', 'Capt. John Harriman', 'Guinan', "Picard's Kid", 'Ensign Kellogg', 'Science Officer', 'Lieutenant']
# 10.91081, max of:
#   3.2777627, sum of:
#     3.2777627, weight(overview:star in 124) [PerFieldSimilarity], result of:
#       3.2777627, score(doc=124,freq=1.0 = termFreq=1.0
# ), product of:
#         3.14339, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           90.0, docFreq
#           2097.0, docCount
#         1.0427477, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           36.67525, avgFieldLength
#           33.0, fieldLength
#   8.666756, sum of:
#     4.064497, weight(title:star in 124) [PerFieldSimilarity], result of:
#       4.064497, score(doc=124,freq=1.0 = termFreq=1.0
# ), product of:
#         4.678802, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           19.0, docFreq
#           2098.0, docCount
#         0.8687046, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.1906579, avgFieldLength
#           3.0, fieldLength
#     4.602259, weight(title:trek in 124) [PerFieldSimilarity], result of:
#       4.602259, score(doc=124,freq=1.0 = termFreq=1.0
# ), product of:
#         5.297841, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           10.0, docFreq
#           2098.0, docCount
#         0.8687046, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.1906579, avgFieldLength
#           3.0, fieldLength
#   10.91081, sum of:
#     5.3700857, weight(cast.name.bigramed:patrick stewart in 124) [PerFieldSimilarity], result of:
#       5.3700857, score(doc=124,freq=1.0 = termFreq=1.0
# ), product of:
#         5.04605, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           13.0, docFreq
#           2097.0, docCount
#         1.0642157, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           19.941345, avgFieldLength
#           17.0, fieldLength
#     5.5407248, weight(cast.name.bigramed:william shatner in 124) [PerFieldSimilarity], result of:
#       5.5407248, score(doc=124,freq=1.0 = termFreq=1.0
# ), product of:
#         5.206393, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           11.0, docFreq
#           2097.0, docCount
#         1.0642157, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           19.941345, avgFieldLength
#           17.0, fieldLength
#
# *************************************
# 3	9.460281		Star Trek IV: The Voyage Home
# Star Trek IV: The Voyage Home
# The key to saving the future can only be found in the past.
# Fugitives of the Federation for their daring rescue of Spock from the doomed Genesis Planet, Admiral Kirk (William Shatner) and his crew begin their journey home to face justice for their actions. But as they near Earth, they find it at the mercy of a mysterious alien presence whose signals are slowly destroying the planet. In a desperate attempt to answer the call of the probe, Kirk and his crew race back to the late twentieth century. However they soon find the world they once knew to be more alien than anything they've encountered in the far reaches of the galaxy!
# 168
# DIRS ['Leonard Nimoy']
# CAST ['William Shatner', 'Leonard Nimoy', 'DeForest Kelley', 'James Doohan', 'George Takei', 'Walter Koenig', 'Nichelle Nichols', 'Jane Wyatt', 'Catherine Hicks', 'Mark Lenard', 'Robin Curtis', 'Robert Ellenstein', 'John Schuck', 'Brock Peters', 'Michael Snyder']
# CHAR ['Admiral/Captain James T. Kirk', 'Captain Spock', 'Dr. Leonard McCoy', 'Montgomery Scott', 'Cmdr. Hikaru Sulu', 'Cmdr. Pavel Chekov', 'Cmdr. Uhura', 'Amanda', 'Dr. Gillian Taylor', 'Ambassador Sarek', 'Lt. Saavik', 'Federation Council President', 'Klingon Ambassador', 'Admiral Cartwright', 'Starfleet Communications Officer']
# 9.460281, max of:
#   9.460281, sum of:
#     3.712444, weight(overview:william in 105) [PerFieldSimilarity], result of:
#       3.712444, score(doc=105,freq=1.0 = termFreq=1.0
# ), product of:
#         4.678325, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           19.0, docFreq
#           2097.0, docCount
#         0.79354125, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           36.67525, avgFieldLength
#           60.0, fieldLength
#     5.747837, weight(overview:shatner in 105) [PerFieldSimilarity], result of:
#       5.747837, score(doc=105,freq=1.0 = termFreq=1.0
# ), product of:
#         7.2432747, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           1.0, docFreq
#           2097.0, docCount
#         0.79354125, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           36.67525, avgFieldLength
#           60.0, fieldLength
#   6.5436654, sum of:
#     3.0688193, weight(title:star in 105) [PerFieldSimilarity], result of:
#       3.0688193, score(doc=105,freq=1.0 = termFreq=1.0
# ), product of:
#         4.678802, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           19.0, docFreq
#           2098.0, docCount
#         0.6558985, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.1906579, avgFieldLength
#           5.0, fieldLength
#     3.4748461, weight(title:trek in 105) [PerFieldSimilarity], result of:
#       3.4748461, score(doc=105,freq=1.0 = termFreq=1.0
# ), product of:
#         5.297841, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           10.0, docFreq
#           2098.0, docCount
#         0.6558985, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.1906579, avgFieldLength
#           5.0, fieldLength
#   5.7937016, sum of:
#     5.7937016, weight(cast.name.bigramed:william shatner in 105) [PerFieldSimilarity], result of:
#       5.7937016, score(doc=105,freq=1.0 = termFreq=1.0
# ), product of:
#         5.206393, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           11.0, docFreq
#           2097.0, docCount
#         1.1128054, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           19.941345, avgFieldLength
#           15.0, fieldLength
#
# *************************************
# 4	8.666756		Star Trek: Insurrection
# Star Trek: Insurrection
# The battle for paradise has begun.
# When an alien race and factions within Starfleet attempt to take over a planet that has "regenerative" properties, it falls upon Captain Picard and the crew of the Enterprise to defend the planet's people as well as the very ideals upon which the Federation itself was founded.
# 200
# DIRS ['Jonathan Frakes']
# CAST ['Patrick Stewart', 'Jonathan Frakes', 'Brent Spiner', 'LeVar Burton', 'Gates McFadden', 'Marina Sirtis', 'F. Murray Abraham', 'Anthony Zerbe', 'Donna Murphy', 'Gregg Henry', 'Michael Dorn']
# CHAR ['Captain Jean-Luc Picard', 'Commander William T. Riker', 'Lt. Commander Data', 'Lt. Commander Geordi La Forge', 'Doctor Beverly Crusher', 'Counselor Deanna Troi', "Ad'har Ru'afo", 'Vice-Adm. Dougherty', 'Anij', 'Gallatin', 'Lt. Commander Worf']
# 8.666756, max of:
#   8.666756, sum of:
#     4.064497, weight(title:star in 225) [PerFieldSimilarity], result of:
#       4.064497, score(doc=225,freq=1.0 = termFreq=1.0
# ), product of:
#         4.678802, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           19.0, docFreq
#           2098.0, docCount
#         0.8687046, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.1906579, avgFieldLength
#           3.0, fieldLength
#     4.602259, weight(title:trek in 225) [PerFieldSimilarity], result of:
#       4.602259, score(doc=225,freq=1.0 = termFreq=1.0
# ), product of:
#         5.297841, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           10.0, docFreq
#           2098.0, docCount
#         0.8687046, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.1906579, avgFieldLength
#           3.0, fieldLength
#   6.028117, sum of:
#     6.028117, weight(cast.name.bigramed:patrick stewart in 225) [PerFieldSimilarity], result of:
#       6.028117, score(doc=225,freq=1.0 = termFreq=1.0
# ), product of:
#         5.04605, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           13.0, docFreq
#           2097.0, docCount
#         1.194621, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           19.941345, avgFieldLength
#           12.0, fieldLength
#
# *************************************
# 5	8.666756		Star Trek: Nemesis
# Star Trek: Nemesis
# A generation's final journey... begins.
# En route to the honeymoon of William Riker to Deanna Troi on her home planet of Betazed, Captain Jean-Luc Picard and the crew of the U.S.S. Enterprise receives word from Starfleet that a coup has resulted in the installation of a new Romulan political leader, Shinzon, who claims to seek peace with the human-backed United Federation of Planets. Once in enemy territory, the captain and his crew make a startling discovery: Shinzon is human, a slave from the Romulan sister planet of Remus, and has a secret, shocking relationship to Picard himself.
# 201
# DIRS ['Stuart Baird']
# CAST ['Patrick Stewart', 'Jonathan Frakes', 'LeVar Burton', 'Brent Spiner', 'Gates McFadden', 'Marina Sirtis', 'Tom Hardy', 'Ron Perlman', 'Shannon Cochran', 'Dina Meyer', 'Michael Dorn', 'Kate Mulgrew', 'Wil Wheaton', 'Whoopi Goldberg', 'Stuart Baird', 'Alan Dale', 'Bryan Singer']
# CHAR ['Captain Jean-Luc Picard', 'Captain William T. Riker', 'Lt. Commander Geordi La Forge', 'Lt. Commander Data', 'Dr. Beverly Crusher', 'Counselor Deanna Troi-Riker', 'Praetor Shinzon', 'The Reman Viceroy', "Senator Tal'aura", 'Commander Donatra', 'Lt. Commander Worf', 'Admiral Janeway', 'Wesley Crusher', 'Guinan', 'Scimitar Computer (voice)', 'Praetor Hiren', 'Kelly (uncredited)']
# 8.666756, max of:
#   3.712444, sum of:
#     3.712444, weight(overview:william in 230) [PerFieldSimilarity], result of:
#       3.712444, score(doc=230,freq=1.0 = termFreq=1.0
# ), product of:
#         4.678325, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           19.0, docFreq
#           2097.0, docCount
#         0.79354125, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           36.67525, avgFieldLength
#           60.0, fieldLength
#   8.666756, sum of:
#     4.064497, weight(title:star in 230) [PerFieldSimilarity], result of:
#       4.064497, score(doc=230,freq=1.0 = termFreq=1.0
# ), product of:
#         4.678802, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           19.0, docFreq
#           2098.0, docCount
#         0.8687046, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.1906579, avgFieldLength
#           3.0, fieldLength
#     4.602259, weight(title:trek in 230) [PerFieldSimilarity], result of:
#       4.602259, score(doc=230,freq=1.0 = termFreq=1.0
# ), product of:
#         5.297841, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           10.0, docFreq
#           2098.0, docCount
#         0.8687046, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.1906579, avgFieldLength
#           3.0, fieldLength
#   5.3700857, sum of:
#     5.3700857, weight(cast.name.bigramed:patrick stewart in 230) [PerFieldSimilarity], result of:
#       5.3700857, score(doc=230,freq=1.0 = termFreq=1.0
# ), product of:
#         5.04605, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           13.0, docFreq
#           2097.0, docCount
#         1.0642157, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           19.941345, avgFieldLength
#           17.0, fieldLength
#
# *************************************
# {'_shards': {'total': 1, 'successful': 1, 'failed': 0}, 'valid': True, 'explanations': [{'index': 'tmdb', 'valid': True, 'explanation': '+((directors.name.bigramed:star trek directors.name.bigramed:trek patrick directors.name.bigramed:patrick stewart directors.name.bigramed:stewart william directors.name.bigramed:william shatner) | (overview:star overview:trek overview:patrick overview:stewart overview:william overview:shatner) | (title:star title:trek title:patrick title:stewart title:william title:shatner) | (cast.name.bigramed:star trek cast.name.bigramed:trek patrick cast.name.bigramed:patrick stewart cast.name.bigramed:stewart william cast.name.bigramed:william shatner)) #*:*'}]}

# %% [markdown]
# # Listing 8 -- Searching fields that work in sync

# %%
usersSearch = 'star trek patrick stewart william shatner'
query = {
    'query': {
        'query_string': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview',
  			     'cast.name', 'directors.name'],  #A    
         }
    },
    'size': 5,
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	14.812269		Hannah Montana: The Movie
# 2	13.610828		Star Trek: Generations
# 3	13.400371		Star Trek V: The Final Frontier
# 4	9.460281		Star Trek IV: The Voyage Home
# 5	8.666756		Star Trek: Insurrection

# %% [markdown]
# # 6.3.5, Listing 9 -- Tuning Term-Centric Search

# %%
usersSearch = 'star trek patrick stewart william shatner'
query = {
    'query': {
        'query_string': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview', 
   'cast.name^10', 'directors.name'], #A
           }
    },
    'size': 5,
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	136.10828		Star Trek: Generations
# 2	85.860634		Miss Congeniality 2: Armed and Fabulous
# 3	83.55811		Conspiracy Theory
# 4	83.12719		Star Trek II: The Wrath of Khan
# 5	82.90338		Bill & Ted's Bogus Journey

# %% [markdown]
# # 6.4.1, Listings 10&11 Combining Fields into Custom All Fields

# %%
mappingSettings = {
    'movie': {
        'properties': {
            # Because of a bug, you have to be very explicit
            # about analyzers for cross_field search
            "title": {
              'type': 'text',
              'analyzer': 'english',
            },
            "overview": {
              'type': 'text',
              'analyzer': 'english',
            },            
            "people": {
              'properties': {
                  'name': {
                      'type': 'text',
                      'analyzer': 'english',
                      'fields': {
                         "bigramed": {
                            "type": "text",
                            "analyzer": "english_bigrams",
                        }     
                      }
                   }
                   
               }                       
            },
            "cast": {
               'properties': {
                  'name': {
                      'type': 'text',
                      'analyzer': 'english',
                      'copy_to': 'people.name',
                      'fields': {
                         "bigramed": {
                            "type": "text",
                            "analyzer": "english_bigrams"
                        }     
                      }
                   }
                   
               }
            },
            "directors": {
               'properties': {
                  'name': {
                      'type': 'text',
                      'analyzer': 'english',
                      'copy_to': 'people.name',                      
                      'fields': {
                         "bigramed": {
                            "type": "text",
                            "analyzer": "english_bigrams"
                        }     
                      }
                   }
                   
               }
            }            
        }
    }
}

reindex(analysisSettings, mappingSettings, movieDict)
# Out:
# Delete TMDB Index <200>
# Create TMDB Index <200>
# Indexing 3051 movies
# Bulk Index into TMDB Index <200>

# %% [markdown]
# # 6.4.1, Listing 12 -- Simple use of a custom all field

# %%
usersSearch = 'patrick stewart william shatner'
query = {
    'query': {
        'match': { 
            'people.name': usersSearch,  #User's query
         }
    },
    'size': 5,
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	13.336635		Star Trek: Generations
# 2	9.898848		Star Trek V: The Final Frontier
# 3	8.233552		Bill & Ted's Bogus Journey
# 4	8.11424		Miss Congeniality 2: Armed and Fabulous
# 5	7.828116		Star Trek II: The Wrath of Khan

# %% [markdown]
# # Listing 13 -- Searching _all

# %%
usersSearch = 'star trek patrick stewart william shatner'
query = {
    'query': {
        'match': { 
            '_all': usersSearch,  #User's query
         }
    },
    'size': 5,
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title

# %% [markdown]
# # 6.4.2, Listing 14 -- Cross Field Search over useful fields

# %%
usersSearch = 'star trek patrick stewart william shatner'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview', 'cast.name', 'directors.name'],
            'type': 'cross_fields',
         }
    },
    'size': 5,
    'explain': True
}
search(query,True)
# Out:
# Num	Relevance Score		Movie Title
# 1	20.928247		Star Trek: Generations
# Star Trek: Generations
# Boldly go.
# Captain Jean-Luc Picard and the crew of the Enterprise-D find themselves at odds with the renegade scientist Soran who is destroying entire star systems. Only one man can help Picard stop Soran's scheme...and he's been dead for seventy-eight years.
# 193
# DIRS ['David Carson']
# CAST ['Patrick Stewart', 'Jonathan Frakes', 'Brent Spiner', 'LeVar Burton', 'Michael Dorn', 'Gates McFadden', 'Marina Sirtis', 'William Shatner', 'James Doohan', 'Walter Koenig', 'Malcolm McDowell', 'Alan Ruck', 'Whoopi Goldberg', 'Thomas Dekker', 'Cameron Oppenheimer', 'Jenette Goldstein', 'Tim Russ']
# CHAR ['Captain Jean-Luc Picard', 'Commander William T. Riker', 'Lt. Commander Data', 'Lt. Commander Geordi La Forge', 'Lt. Commander Worf', 'Dr. Beverly Crusher', 'Commander Deanna Troi', 'James T. Kirk', 'Montgomery Scott', 'Pavel Chekov', 'Dr. Tolian Soran', 'Capt. John Harriman', 'Guinan', "Picard's Kid", 'Ensign Kellogg', 'Science Officer', 'Lieutenant']
# 20.928247, sum of:
#   3.2162156, max of:
#     3.2162156, weight(overview:star in 124) [PerFieldSimilarity], result of:
#       3.2162156, score(doc=124,freq=1.0 = termFreq=1.0
# ), product of:
#         3.0903976, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           70.0, docFreq
#           1549.0, docCount
#         1.0407126, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           36.48935, avgFieldLength
#           33.0, fieldLength
#     2.6804085, weight(title:star in 124) [PerFieldSimilarity], result of:
#       2.6804085, score(doc=124,freq=1.0 = termFreq=1.0
# ), product of:
#         3.0769577, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           71.0, docFreq
#           1550.0, docCount
#         0.87112296, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.2032259, avgFieldLength
#           3.0, fieldLength
#   4.351503, max of:
#     4.351503, weight(title:trek in 124) [PerFieldSimilarity], result of:
#       4.351503, score(doc=124,freq=1.0 = termFreq=1.0
# ), product of:
#         4.99528, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           10.0, docFreq
#           1550.0, docCount
#         0.87112296, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.2032259, avgFieldLength
#           3.0, fieldLength
#   2.6209755, max of:
#     2.6209755, weight(cast.name:patrick in 124) [PerFieldSimilarity], result of:
#       2.6209755, score(doc=124,freq=1.0 = termFreq=1.0
# ), product of:
#         2.4907262, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           128.0, docFreq
#           1550.0, docCount
#         1.0522937, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           38.70129, avgFieldLength
#           34.0, fieldLength
#   3.713484, max of:
#     3.713484, weight(cast.name:stewart in 124) [PerFieldSimilarity], result of:
#       3.713484, score(doc=124,freq=1.0 = termFreq=1.0
# ), product of:
#         3.5289428, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           45.0, docFreq
#           1550.0, docCount
#         1.0522937, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           38.70129, avgFieldLength
#           34.0, fieldLength
#   1.8652977, max of:
#     1.8652977, weight(cast.name:william in 124) [PerFieldSimilarity], result of:
#       1.8652977, score(doc=124,freq=1.0 = termFreq=1.0
# ), product of:
#         1.7726018, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           263.0, docFreq
#           1550.0, docCount
#         1.0522937, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           38.70129, avgFieldLength
#           34.0, fieldLength
#   5.1607723, max of:
#     5.1607723, weight(cast.name:shatner in 124) [PerFieldSimilarity], result of:
#       5.1607723, score(doc=124,freq=1.0 = termFreq=1.0
# ), product of:
#         4.9043083, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           11.0, docFreq
#           1550.0, docCount
#         1.0522937, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           38.70129, avgFieldLength
#           34.0, fieldLength
#
# *************************************
# 2	14.765699		Star Trek: Nemesis
# Star Trek: Nemesis
# A generation's final journey... begins.
# En route to the honeymoon of William Riker to Deanna Troi on her home planet of Betazed, Captain Jean-Luc Picard and the crew of the U.S.S. Enterprise receives word from Starfleet that a coup has resulted in the installation of a new Romulan political leader, Shinzon, who claims to seek peace with the human-backed United Federation of Planets. Once in enemy territory, the captain and his crew make a startling discovery: Shinzon is human, a slave from the Romulan sister planet of Remus, and has a secret, shocking relationship to Picard himself.
# 201
# DIRS ['Stuart Baird']
# CAST ['Patrick Stewart', 'Jonathan Frakes', 'LeVar Burton', 'Brent Spiner', 'Gates McFadden', 'Marina Sirtis', 'Tom Hardy', 'Ron Perlman', 'Shannon Cochran', 'Dina Meyer', 'Michael Dorn', 'Kate Mulgrew', 'Wil Wheaton', 'Whoopi Goldberg', 'Stuart Baird', 'Alan Dale', 'Bryan Singer']
# CHAR ['Captain Jean-Luc Picard', 'Captain William T. Riker', 'Lt. Commander Geordi La Forge', 'Lt. Commander Data', 'Dr. Beverly Crusher', 'Counselor Deanna Troi-Riker', 'Praetor Shinzon', 'The Reman Viceroy', "Senator Tal'aura", 'Commander Donatra', 'Lt. Commander Worf', 'Admiral Janeway', 'Wesley Crusher', 'Guinan', 'Scimitar Computer (voice)', 'Praetor Hiren', 'Kelly (uncredited)']
# 14.7657, sum of:
#   2.6804085, max of:
#     2.6804085, weight(title:star in 494) [PerFieldSimilarity], result of:
#       2.6804085, score(doc=494,freq=1.0 = termFreq=1.0
# ), product of:
#         3.0769577, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           71.0, docFreq
#           1550.0, docCount
#         0.87112296, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.2032259, avgFieldLength
#           3.0, fieldLength
#   4.351503, max of:
#     4.351503, weight(title:trek in 494) [PerFieldSimilarity], result of:
#       4.351503, score(doc=494,freq=1.0 = termFreq=1.0
# ), product of:
#         4.99528, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           10.0, docFreq
#           1550.0, docCount
#         0.87112296, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.2032259, avgFieldLength
#           3.0, fieldLength
#   2.6209755, max of:
#     2.6209755, weight(cast.name:patrick in 494) [PerFieldSimilarity], result of:
#       2.6209755, score(doc=494,freq=1.0 = termFreq=1.0
# ), product of:
#         2.4907262, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           128.0, docFreq
#           1550.0, docCount
#         1.0522937, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           38.70129, avgFieldLength
#           34.0, fieldLength
#   3.713484, max of:
#     3.713484, weight(cast.name:stewart in 494) [PerFieldSimilarity], result of:
#       3.713484, score(doc=494,freq=1.0 = termFreq=1.0
# ), product of:
#         3.5289428, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           45.0, docFreq
#           1550.0, docCount
#         1.0522937, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           38.70129, avgFieldLength
#           34.0, fieldLength
#   1.3993288, max of:
#     1.3993288, weight(overview:william in 494) [PerFieldSimilarity], result of:
#       1.3993288, score(doc=494,freq=1.0 = termFreq=1.0
# ), product of:
#         1.7681689, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           264.0, docFreq
#           1549.0, docCount
#         0.79139996, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           36.48935, avgFieldLength
#           60.0, fieldLength
#
# *************************************
# 3	14.249481		Star Trek: Insurrection
# Star Trek: Insurrection
# The battle for paradise has begun.
# When an alien race and factions within Starfleet attempt to take over a planet that has "regenerative" properties, it falls upon Captain Picard and the crew of the Enterprise to defend the planet's people as well as the very ideals upon which the Federation itself was founded.
# 200
# DIRS ['Jonathan Frakes']
# CAST ['Patrick Stewart', 'Jonathan Frakes', 'Brent Spiner', 'LeVar Burton', 'Gates McFadden', 'Marina Sirtis', 'F. Murray Abraham', 'Anthony Zerbe', 'Donna Murphy', 'Gregg Henry', 'Michael Dorn']
# CHAR ['Captain Jean-Luc Picard', 'Commander William T. Riker', 'Lt. Commander Data', 'Lt. Commander Geordi La Forge', 'Doctor Beverly Crusher', 'Counselor Deanna Troi', "Ad'har Ru'afo", 'Vice-Adm. Dougherty', 'Anij', 'Gallatin', 'Lt. Commander Worf']
# 14.249481, sum of:
#   2.6804085, max of:
#     2.6804085, weight(title:star in 489) [PerFieldSimilarity], result of:
#       2.6804085, score(doc=489,freq=1.0 = termFreq=1.0
# ), product of:
#         3.0769577, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           71.0, docFreq
#           1550.0, docCount
#         0.87112296, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.2032259, avgFieldLength
#           3.0, fieldLength
#   4.351503, max of:
#     4.351503, weight(title:trek in 489) [PerFieldSimilarity], result of:
#       4.351503, score(doc=489,freq=1.0 = termFreq=1.0
# ), product of:
#         4.99528, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           10.0, docFreq
#           1550.0, docCount
#         0.87112296, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.2032259, avgFieldLength
#           3.0, fieldLength
#   2.986375, max of:
#     2.986375, weight(cast.name:patrick in 489) [PerFieldSimilarity], result of:
#       2.986375, score(doc=489,freq=1.0 = termFreq=1.0
# ), product of:
#         2.4907262, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           128.0, docFreq
#           1550.0, docCount
#         1.1989977, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           38.70129, avgFieldLength
#           23.0, fieldLength
#   4.2311945, max of:
#     4.2311945, weight(cast.name:stewart in 489) [PerFieldSimilarity], result of:
#       4.2311945, score(doc=489,freq=1.0 = termFreq=1.0
# ), product of:
#         3.5289428, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           45.0, docFreq
#           1550.0, docCount
#         1.1989977, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           38.70129, avgFieldLength
#           23.0, fieldLength
#
# *************************************
# 4	13.218537		Star Trek II: The Wrath of Khan
# Star Trek II: The Wrath of Khan
# At the end of the universe lies the beginning of vengeance.
# Admiral James T. Kirk is feeling old; the prospect of accompanying his old ship the Enterprise on a two week cadet cruise is not making him feel any younger. But the training cruise becomes a a life or death struggle when Khan escapes from years of exile and captures the power of creation itself.
# 154
# DIRS ['Nicholas Meyer']
# CAST ['William Shatner', 'Leonard Nimoy', 'DeForest Kelley', 'James Doohan', 'George Takei', 'Nichelle Nichols', 'Walter Koenig', 'Ricardo Montalban', 'Bibi Besch', 'Merritt Butrick', 'Kirstie Alley', 'Paul Winfield']
# CHAR ['Admiral James T. Kirk', 'Captain Spock', 'Dr. Leonard McCoy', 'Montgomery Scott', 'Cmdr. Hikaru Sulu', 'Cmdr. Uhura', 'Cmdr. Pavel Chekov', 'Khan Noonien Singh', 'Dr. Carol Marcus', 'Dr. David Marcus', 'Lt. Saavik', 'Captain Clark Terrell']
# 13.218538, sum of:
#   2.0252473, max of:
#     2.0252473, weight(title:star in 94) [PerFieldSimilarity], result of:
#       2.0252473, score(doc=94,freq=1.0 = termFreq=1.0
# ), product of:
#         3.0769577, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           71.0, docFreq
#           1550.0, docCount
#         0.65819794, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.2032259, avgFieldLength
#           5.0, fieldLength
#   3.2878828, max of:
#     3.2878828, weight(title:trek in 94) [PerFieldSimilarity], result of:
#       3.2878828, score(doc=94,freq=1.0 = termFreq=1.0
# ), product of:
#         4.99528, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           10.0, docFreq
#           1550.0, docCount
#         0.65819794, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.2032259, avgFieldLength
#           5.0, fieldLength
#   2.0987463, max of:
#     2.0987463, weight(cast.name:william in 94) [PerFieldSimilarity], result of:
#       2.0987463, score(doc=94,freq=1.0 = termFreq=1.0
# ), product of:
#         1.7726018, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           263.0, docFreq
#           1550.0, docCount
#         1.1839919, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           38.70129, avgFieldLength
#           24.0, fieldLength
#   5.8066616, max of:
#     5.8066616, weight(cast.name:shatner in 94) [PerFieldSimilarity], result of:
#       5.8066616, score(doc=94,freq=1.0 = termFreq=1.0
# ), product of:
#         4.9043083, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           11.0, docFreq
#           1550.0, docCount
#         1.1839919, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           38.70129, avgFieldLength
#           24.0, fieldLength
#
# *************************************
# 5	13.006065		Star Trek: First Contact
# Star Trek: First Contact
# Resistance is futile.
# The Borg, a relentless race of cyborgs, are on a direct course for Earth. Violating orders to stay away from the battle, Captain Picard and the crew of the newly-commissioned USS Enterprise E pursue the Borg back in time to prevent the invaders from changing Federation history and assimilating the galaxy.
# 199
# DIRS ['Jonathan Frakes']
# CAST ['James Cromwell', 'Alfre Woodard', 'Alice Krige', 'Neal McDonough', 'Patrick Stewart', 'Brent Spiner', 'LeVar Burton', 'Michael Dorn', 'Gates McFadden', 'Marina Sirtis', 'Jonathan Frakes', 'Dwight Schultz', 'Cameron Oppenheimer']
# CHAR ['Dr. Zefram Cochrane', 'Lily Sloane', 'Borg Queen', 'Lieutenant Hawk', 'Captain Jean-Luc Picard', 'Lt. Commander Data', 'Commander Geordi La Forge', 'Lieutenant Commander Worf', 'Commander Beverly Crusher', 'Ships Counselor Commander Deanna Troi', 'Commander William Riker', 'Lt. Barclay', 'Ensign Kellogg']
# 13.006065, sum of:
#   2.3072195, max of:
#     2.3072195, weight(title:star in 129) [PerFieldSimilarity], result of:
#       2.3072195, score(doc=129,freq=1.0 = termFreq=1.0
# ), product of:
#         3.0769577, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           71.0, docFreq
#           1550.0, docCount
#         0.7498379, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.2032259, avgFieldLength
#           4.0, fieldLength
#   3.74565, max of:
#     3.74565, weight(title:trek in 129) [PerFieldSimilarity], result of:
#       3.74565, score(doc=129,freq=1.0 = termFreq=1.0
# ), product of:
#         4.99528, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           10.0, docFreq
#           1550.0, docCount
#         0.7498379, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           2.2032259, avgFieldLength
#           4.0, fieldLength
#   2.8769865, max of:
#     2.8769865, weight(cast.name:patrick in 129) [PerFieldSimilarity], result of:
#       2.8769865, score(doc=129,freq=1.0 = termFreq=1.0
# ), product of:
#         2.4907262, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           128.0, docFreq
#           1550.0, docCount
#         1.1550794, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           38.70129, avgFieldLength
#           26.0, fieldLength
#   4.076209, max of:
#     4.076209, weight(cast.name:stewart in 129) [PerFieldSimilarity], result of:
#       4.076209, score(doc=129,freq=1.0 = termFreq=1.0
# ), product of:
#         3.5289428, idf, computed as log(1 + (docCount - docFreq + 0.5) / (docFreq + 0.5)) from:
#           45.0, docFreq
#           1550.0, docCount
#         1.1550794, tfNorm, computed as (freq * (k1 + 1)) / (freq + k1 * (1 - b + b * fieldLength / avgFieldLength)) from:
#           1.0, termFreq=1.0
#           1.2, parameter k1
#           0.75, parameter b
#           38.70129, avgFieldLength
#           26.0, fieldLength
#
# *************************************
# {'_shards': {'total': 1, 'successful': 1, 'failed': 0}, 'valid': True, 'explanations': [{'index': 'tmdb', 'valid': True, 'explanation': '+(blended(terms:[cast.name:star, overview:star, directors.name:star, title:star]) blended(terms:[cast.name:trek, overview:trek, directors.name:trek, title:trek]) blended(terms:[cast.name:patrick, overview:patrick, directors.name:patrick, title:patrick]) blended(terms:[cast.name:stewart, overview:stewart, directors.name:stewart, title:stewart]) blended(terms:[cast.name:william, overview:william, directors.name:william, title:william]) blended(terms:[cast.name:shatner, overview:shatner, directors.name:shatner, title:shatner])) #*:*'}]}

# %% [markdown]
# # 6.5.1 -- Listing 15 -- Our Search combining term-centric all field (people.name) w/ other fields

# %%
usersSearch = 'star trek patrick stewart william shatner'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview', 'people.name'],
            'type': 'most_fields',
         }
    },
    'size': 5,
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	24.762457		Star Trek: Generations
# 2	22.55778		Star Trek IV: The Voyage Home
# 3	18.088171		Star Trek: Nemesis
# 4	16.215742		Hannah Montana: The Movie
# 5	16.101814		Star Trek V: The Final Frontier

# %% [markdown]
# # 6.5.2, Listing 16 -- Searching two field groupings – people and text

# %%
usersSearch = 'star trek patrick stewart william shatner'
query = {
    'query': {
        'bool': {
            'should': [ #A
                {
                   'multi_match': { 
                      'query': usersSearch,  #User's query
                      'fields': ['directors.name.bigramed', #B 
                                 'cast.name.bigramed'],
                      'type': 'cross_fields'
                      }
                 },
                {
                   'multi_match': {
                     'query': usersSearch,  #User's query
                     'fields': ['overview', 'title'],
                     'type': 'cross_fields'                                
                   }
                },
            ]
        }
    },
    'size': 5,
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	19.84193		Star Trek IV: The Voyage Home
# 2	18.392088		Star Trek: Generations
# 3	16.154388		Star Trek: Nemesis
# 4	14.226931		Hannah Montana: The Movie
# 5	13.281178		Star Trek: Insurrection

# %% [markdown]
# # 6.5.3 Listing 17 Greedy Term-Centric Paired With Highly Discriminating Like Fields

# %%
usersSearch = 'star trek patrick stewart william shatner'
query = {
    'query': {
        'bool': {
            'should': [ #A
                {
                   'multi_match': { 
                      'query': usersSearch,  #User's query
                      'fields': ['directors.name.bigramed', #B 
				      'cast.name.bigramed'],
                      'type': 'cross_fields'
                   }
                 },
                {
                   'multi_match': {
                     'query': usersSearch,  #User's query
                     'fields': ['overview', 'title', #C
                                 'directors.name', 'cast.name'],
                     'type': 'cross_fields'                                
                   }
                },
            ]
        }
    },
    'size': 5,
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	31.752617		Star Trek: Generations
# 2	20.498749		Star Trek: Insurrection
# 3	20.33969		Star Trek: Nemesis
# 4	19.107498		Star Trek: First Contact
# 5	19.104988		Star Trek II: The Wrath of Khan
